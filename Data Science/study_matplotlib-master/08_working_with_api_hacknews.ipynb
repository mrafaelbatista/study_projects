# %% [markdown]
# # API de Hacker News

# %%
import requests
from operator import itemgetter

#Faz uma chamada de API e armazena a resposta
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print("Status code:", r.status_code)

# Processa informações sobre cada artigo submetido
submission_ids = r.json()
submission_dicts = []

for submission_id in submission_ids[:30]:
    # Cria uma chamada de API separada para cada artigo submetido
    url = ('https://hacker-news.firebaseio.com/v0/item/' + str(submission_id) + '.json')
    submission_r = requests.get(url)
    print(submission_r.status_code)
    response_dict = submission_r.json()
    
    submission_dict = {
        'title': response_dict['title'],
        'link': 'https://hacker-news.firebaseio.com/v0/item/' + str(submission_id),
        'comments': response_dict.get('descendants', 0)
    }
    submission_dicts.append(submission_dict)
    
submission_dicts = sorted(submission_dicts, key=itemgetter('comments'), reverse=True)

for submission_dict in submission_dicts:
    print("\nTitle:", submission_dict['title'])
    print("Discussion link:", submission_dict['link'])
    print("Comments:", submission_dict['comments'])
# Out:
# Status code: 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#
# Title: Every Google result now looks like an ad
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22107823
# Comments: 669
#
# Title: Apple dropped plan for encrypting backups after FBI complained
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22106536
# Comments: 543
#
# Title: Tricks to start working despite not feeling like it
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22105229
# Comments: 320
#
# Title: How Germany is able to run the world’s second largest export economy
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22106906
# Comments: 272
#
# Title: WordPad Is Gettings Ads in Windows 10
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22106743
# Comments: 243
#
# Title: Cloudflare is turning off the internet for me
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22109969
# Comments: 206
#
# Title: Amazon to ramp up counterfeit reporting to law enforcement
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22106305
# Comments: 185
#
# Title: Why Learn Awk? (2016)
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22108680
# Comments: 172
#
# Title: Why do we fall into the rewrite trap?
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22106367
# Comments: 149
#
# Title: Jeff Bezos's phone 'hacked by Saudi crown prince'
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22111560
# Comments: 145
#
# Title: First Case of New Coronavirus Detected in U.S.
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22110873
# Comments: 142
#
# Title: WikiHow’s art is made by a network of freelancers, mostly in the Philippines
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22107260
# Comments: 90
#
# Title: How to Kill a Startup Idea with Google Keyword Planner and AdWords: A Case Study
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22110004
# Comments: 77
#
# Title: A 60 GHz phased array for $10
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22109708
# Comments: 74
#
# Title: PHP in 2020
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22111518
# Comments: 73
#
# Title: 28-Key Mechanical Keyboard
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22104550
# Comments: 64
#
# Title: ACM costs vs. arxiv.org costs
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22103763
# Comments: 49
#
# Title: Seq – A Language for Bioinformatics
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22107510
# Comments: 41
#
# Title: Why Rust closures are somewhat hard
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22108957
# Comments: 38
#
# Title: Stack Overflow is forming a moderator council
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22111385
# Comments: 34
#
# Title: Show HN: Train a language model to talk like you
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22107144
# Comments: 29
#
# Title: Friend of a Friend: The Facebook That Could Have Been
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22111827
# Comments: 28
#
# Title: NomadBSD
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22111254
# Comments: 23
#
# Title: Introducing the Cruise Origin
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22113745
# Comments: 12
#
# Title: Who Can Name the Bigger Number? (1999)
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22112854
# Comments: 10
#
# Title: I'm building an open, crowdsourced database of ML models
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22107556
# Comments: 10
#
# Title: Open-source light-sheet microscopes for imaging cleared tissue
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22104511
# Comments: 3
#
# Title: Able Health Is Seeking a Health IT Product Manager
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22113377
# Comments: 0
#
# Title: Fantastic Bugs and Where to Find Them
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22100273
# Comments: 0
#
# Title: The Edge of Emulation
# Discussion link: https://hacker-news.firebaseio.com/v0/item/22101158
# Comments: 0
